# %% [markdown]
# ## The purprose of this notebook is to research on sql fine tuned embedding models from hugging face
# * The main objective is to assess how well this model can provide an accurate cosine similarity score between two sql queries.
# * We will compare this with continuous_eval sql metrics score and SequenceMatcher from difflib

# %%
from typing import Dict, List
from difflib import SequenceMatcher
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from continuous_eval.metrics.code.sql import SQLASTSimilarity
from sqlglot import parse_one
from sqlglot.diff import diff

# %%
embedding_model_a = SentenceTransformer("s2593817/sft-sql-embedding")
embedding_model_b = SentenceTransformer("RaduGabriel/BGE-M3-SQL")
embedding_model_c = SentenceTransformer("dat-ai/bge-base-for_text2sql")
SQLAST_METRIC = SQLASTSimilarity()

# %%
def calculate_cosine_similarity(query_a:str, query_b:str, embedding_model: SentenceTransformer) -> float:
    embeddings = embedding_model.encode([query_a, query_b])
    cosine_similarity_score = embedding_model.similarity(embeddings, embeddings)
    return cosine_similarity_score[0][1]

def calculate_sequence_matcher_similarity(query_a:str, query_b:str) -> float:
    return SequenceMatcher(None, query_a, query_b).ratio()

def calculate_sql_ast_similarity(query_a: str, query_b: str) -> float:
    return SQLAST_METRIC.compute(answer=query_a, ground_truth_answers=query_b)["SQL_AST_Similarity"]

def compare_scores(queries: Dict[str, Dict[str, List[str]]],
                   embedding_models: Dict[str, SentenceTransformer]
                  ) -> pd.DataFrame:
    dfs = []
    for model_name, embedding_model in embedding_models.items():
        cosine_scores = []
        seq_matcher_scores = []
        ast_scores = []
        categories = []
        sub_categories = []
        queries_a = []
        queries_b = []
        for category, sub_category_queries in queries.items():
            for sub_category, query_list in sub_category_queries.items():
                query_a, query_b = query_list
                cosine_similarity_score = calculate_cosine_similarity(query_a, query_b, embedding_model)
                sequence_matcher_score = calculate_sequence_matcher_similarity(query_a, query_b)
                sql_ast_metric = calculate_sql_ast_similarity(query_a, query_b)
                cosine_scores.append(cosine_similarity_score)
                seq_matcher_scores.append(sequence_matcher_score)
                ast_scores.append(sql_ast_metric)
                categories.append(category)
                sub_categories.append(sub_category)
                queries_a.append(query_a)
                queries_b.append(query_b)
        df = pd.DataFrame({
            "model_name": [model_name]*len(cosine_scores),
            "category": categories,
            "sub_categories": sub_categories,
            "cosine_scores": cosine_scores,
            "ast_scores": ast_scores,
            "seq_matcher_score": seq_matcher_scores,
            "query_a": query_a,
            "query_b": query_b
        })
        dfs.append(df)
    return pd.concat(dfs)

# %%
QUERIES  = {
    "DIFFERENT MEANING":{
        "DIFFERENT_QUERY_STRUCTURE":[
            """
                SELECT
                    age,
                    hire_date,
                    department,
                    tenure
                FROM
                    employee_table
                QUALIFY max(salary) over (partition by hire_date) = salary
            """,
            """
                SELECT
                    max(salary)
                FROM 
                    employee_table
                GROUP BY age
            """
        ],
        "logic_filter_comparison":[
            """
                SELECT
                    DISTINCT ACCOUNT_ID
                FROM 
                    transactions
                WHERE
                    TRANSACTION_DATE > '2025-07-01'
            """,
             """
                SELECT
                    DISTINCT ACCOUNT_ID
                FROM 
                    transactions
                WHERE
                    TRANSACTION_DATE < '2025-07-01'
            """ 
        ],
        "logic_filter_equal_check":[
            """
                SELECT
                    DISTINCT ACCOUNT_ID
                FROM 
                    transactions
                WHERE
                    TRANSACTION_DATE <> '2025-07-01'
            """,
             """
                SELECT
                    DISTINCT ACCOUNT_ID
                FROM 
                    transactions
                WHERE
                    TRANSACTION_DATE = '2025-07-01'
            """
        ],
        "col name changes": [
            """
                SELECT
                    department
                FROM
                    employee_table
                QUALIFY max(salary) over (partition by hire_date) = salary
            """,
            """
                SELECT
                    employee_name 
                FROM
                    employee_table
                QUALIFY max(hire_date) over (partition by department) = hire_date
            """
        ],
        "having versus where":[
            "SELECT department FROM employees WHERE salary > 100000",
            "SELECT department FROM employees GROUP BY department HAVING AVG(salary) > 100000"
        ],
        "difference joins":[
            "SELECT e.name, d.name FROM employees e INNER JOIN departments d ON e.dept_id = d.id",
            "SELECT e.name, d.name FROM employees e LEFT JOIN departments d ON e.dept_id = d.id"
        ]
    },
    "SAME MEAING": {
        "column order change only":[
            """
                SELECT 
                    log_date,
                    device_name,
                    department,
                    application_name,
                    device_id
                FROM
                    device_tracking
                ORDER BY log_date, device_id
            """,
            """
                SELECT 
                    device_id,
                    device_name,
                    application_name,
                    department,
                    log_date
                FROM
                    device_tracking
                ORDER BY device_id, log_date
            """
        ],
        "aliases":[
            """
                SELECT 
                    tbl.log_date as "log date",
                    tbl.device_name as "device name",
                    tbl.department,
                    tbl.application_name,
                    tbl.device_id as "device id"
                FROM
                    device_tracking as tbl
                GROUP BY 1,2,3,4,5
            """,
            """
                SELECT 
                    device_id,
                    device_name,
                    application_name,
                    department,
                    log_date
                FROM
                    device_tracking
                GROUP BY ALL
            """                
        ],
        "date function between":[
            """
                SELECT
                    customer_name,
                    create_date,
                    last_login_time
                FROM 
                    customers 
                WHERE 
                    last_login_time >= '2025-07-11' and last_login_time <= '2025-07-15'
            """,
            """
                SELECT
                    customer_name,
                    create_date,
                    last_login_time
                FROM 
                    customers 
                WHERE 
                    last_login_time BETWEEN '2025-07-11' and '2025-07-15'
            """
        ],
        "date function custom":[
            """
                SELECT
                    customer_name,
                    create_date,
                    last_login_time
                FROM 
                    customers 
                WHERE 
                    last_login_time >= TRUNC(SYSDATE) - 7
            """,
            """
                SELECT
                    customer_name,
                    create_date,
                    last_login_time
                FROM 
                    customers 
                WHERE 
                    last_login_time >= CURRENT_DATE - INTERVAL '7' DAY
            """
        ],
        "extract versus day/year":[
            """
                SELECT
                    customer_name,
                    YEAR(create_date) as year,
                    DAY(last_login_time) as DAY
                FROM 
                    customers 
            """,
            """
                SELECT
                    customer_name,
                    EXTRACT(YEAR FROM create_date) as year,
                    EXTRACT(DAY FROM last_login_time) as DAY
                FROM 
                    customers 
            """
        ],
        "regex and str":[
            """
                SELECT
                    LEFT(DeviceName, 7),
                    RIGHT(DeviceName, 3),
                    IpSource || '-' || IpTarget,
                    COUNT(*)
                FROM servers
                WHERE DeviceName Like '%HOME%' and IpSource != '172.16.14.16'
            """,
            """
                SELECT
                    SUBSTRING(DeviceName, 1, 7),
                    SUBSTRING(DeviceName, LEN(DeviceName)-2, LEN(DeviceName)),
                    CONCAT(IpSource, '-', IpTarget),
                    COUNT(1),
                FROM servers
                WHERE DeviceName REGEXP '%HOME%' and IpSource <> '172.16.14.16'
            """ 
        ],
        "qualify versus cte":[
            """
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM 
                    CUSTOMER_PURCHASES
                QUALIFY MAX(SIGN_UP_DATE) OVER (PARTITION BY STATE) = SIGN_UP_DATE
            """,
            """
                WITH stateData As (
                    SELECT
                        USER_ID,
                        SIGN_UP_DATE,
                        STATE,
                        PURCHASE,
                        ROW_NUMBER() OVER (PARTITION BY STATE) as row_number
                    FROM
                        CUSTOMER_PURCHASES        
                )
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM stateData
                WHERE row_number = 1
            """
        ],
        "cte versus subquery":[
            """
                WITH stateData As (
                    SELECT
                        USER_ID,
                        SIGN_UP_DATE,
                        STATE,
                        PURCHASE,
                        ROW_NUMBER() OVER (PARTITION BY STATE) as row_number
                    FROM
                        CUSTOMER_PURCHASES        
                )
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM stateData
                WHERE row_number = 1
            """,
            """
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM (
                    SELECT
                        USER_ID,
                        SIGN_UP_DATE,
                        STATE,
                        PURCHASE,
                        ROW_NUMBER() OVER (PARTITION BY STATE) as row_number
                    FROM
                        CUSTOMER_PURCHASES
                ) 
                WHERE row_number = 1
            """
        ],
        "qualify versus subquery":[
             """
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM 
                    CUSTOMER_PURCHASES
                QUALIFY MAX(SIGN_UP_DATE) OVER (PARTITION BY STATE) = SIGN_UP_DATE
            """,
            """
                SELECT
                    USER_ID,
                    SIGN_UP_DATE,
                    STATE,
                    PURCHASE
                FROM (
                    SELECT
                        USER_ID,
                        SIGN_UP_DATE,
                        STATE,
                        PURCHASE,
                        ROW_NUMBER() OVER (PARTITION BY STATE) as row_number
                    FROM
                        CUSTOMER_PURCHASES
                ) 
                WHERE row_number = 1
            """
        ],
        "over versus group by":[
            "SELECT department, MAX(salary) FROM employees GROUP BY department",
            "SELECT department, MAX(salary) OVER (PARTITION BY department) FROM employees"
        ],
        "join versus subquery":[
            "SELECT name FROM students WHERE class_id IN (SELECT id FROM classes WHERE teacher = 'Smith')",
            "SELECT name FROM students s LEFT JOIN classes c ON s.class_id = c.id WHERE c.teacher = 'Smith'"
        ]      
    }
}

EMBEDDING_MODELS = {
    "s2593817/sft-sql-embedding": embedding_model_a,
    "RaduGabriel/BGE-M3-SQL": embedding_model_b,
    "dat-ai/bge-base-for_text2sql": embedding_model_c    
}

# %%
result = compare_scores(
    queries=QUERIES,
    embedding_models=EMBEDDING_MODELS
)

# %% [markdown]
# ### Display results by models

# %%
result[result.model_name == "s2593817/sft-sql-embedding"].sort_values(by=["category", "sub_categories"])
# Out:
#                     model_name           category             sub_categories  \
# 0   s2593817/sft-sql-embedding  DIFFERENT MEANING  DIFFERENT_QUERY_STRUCTURE
# 3   s2593817/sft-sql-embedding  DIFFERENT MEANING           col name changes
# 5   s2593817/sft-sql-embedding  DIFFERENT MEANING           difference joins
# 4   s2593817/sft-sql-embedding  DIFFERENT MEANING        having versus where
# 1   s2593817/sft-sql-embedding  DIFFERENT MEANING    logic_filter_comparison
# 2   s2593817/sft-sql-embedding  DIFFERENT MEANING   logic_filter_equal_check
# 7   s2593817/sft-sql-embedding        SAME MEAING                    aliases
# 6   s2593817/sft-sql-embedding        SAME MEAING   column order change only
# 13  s2593817/sft-sql-embedding        SAME MEAING        cte versus subquery
# 8   s2593817/sft-sql-embedding        SAME MEAING      date function between
# 9   s2593817/sft-sql-embedding        SAME MEAING       date function custom
# 10  s2593817/sft-sql-embedding        SAME MEAING    extract versus day/year
# 16  s2593817/sft-sql-embedding        SAME MEAING       join versus subquery
# 15  s2593817/sft-sql-embedding        SAME MEAING       over versus group by
# 12  s2593817/sft-sql-embedding        SAME MEAING         qualify versus cte
# 14  s2593817/sft-sql-embedding        SAME MEAING    qualify versus subquery
# 11  s2593817/sft-sql-embedding        SAME MEAING              regex and str
#
#      cosine_scores  ast_scores  seq_matcher_score  \
# 0   tensor(0.2638)    0.431818           0.637615
# 3   tensor(0.9711)    0.187500           0.786241
# 5   tensor(0.9739)    0.875000           0.957576
# 4   tensor(0.5572)    0.600000           0.746269
# 1   tensor(0.9975)    0.750000           0.995122
# 2   tensor(0.9796)    0.750000           0.992701
# 7   tensor(0.5448)    0.257576           0.420891
# 6   tensor(0.9959)    0.904762           0.476821
# 13  tensor(0.9756)    0.807692           0.699559
# 8   tensor(0.9567)    0.675000           0.952862
# 9   tensor(0.9147)    0.289474           0.901961
# 10  tensor(0.9537)    0.444444           0.758621
# 16  tensor(0.5896)    0.134615           0.688172
# 15  tensor(0.7444)    0.708333           0.638298
# 12  tensor(0.7592)    0.346154           0.470852
# 14  tensor(0.8407)    0.338235           0.494649
# 11  tensor(0.8834)    0.342105           0.633333
#
#                                               query_a  \
# 0   SELECT name FROM students WHERE class_id IN (S...
# 3   SELECT name FROM students WHERE class_id IN (S...
# 5   SELECT name FROM students WHERE class_id IN (S...
# 4   SELECT name FROM students WHERE class_id IN (S...
# 1   SELECT name FROM students WHERE class_id IN (S...
# 2   SELECT name FROM students WHERE class_id IN (S...
# 7   SELECT name FROM students WHERE class_id IN (S...
# 6   SELECT name FROM students WHERE class_id IN (S...
# 13  SELECT name FROM students WHERE class_id IN (S...
# 8   SELECT name FROM students WHERE class_id IN (S...
# 9   SELECT name FROM students WHERE class_id IN (S...
# 10  SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
# 12  SELECT name FROM students WHERE class_id IN (S...
# 14  SELECT name FROM students WHERE class_id IN (S...
# 11  SELECT name FROM students WHERE class_id IN (S...
#
#                                               query_b
# 0   SELECT name FROM students s LEFT JOIN classes ...
# 3   SELECT name FROM students s LEFT JOIN classes ...
# 5   SELECT name FROM students s LEFT JOIN classes ...
# 4   SELECT name FROM students s LEFT JOIN classes ...
# 1   SELECT name FROM students s LEFT JOIN classes ...
# 2   SELECT name FROM students s LEFT JOIN classes ...
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 6   SELECT name FROM students s LEFT JOIN classes ...
# 13  SELECT name FROM students s LEFT JOIN classes ...
# 8   SELECT name FROM students s LEFT JOIN classes ...
# 9   SELECT name FROM students s LEFT JOIN classes ...
# 10  SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...
# 12  SELECT name FROM students s LEFT JOIN classes ...
# 14  SELECT name FROM students s LEFT JOIN classes ...
# 11  SELECT name FROM students s LEFT JOIN classes ...

# %%
result[result.model_name == "RaduGabriel/BGE-M3-SQL"].sort_values(by=["category", "sub_categories"])
# Out:
#                 model_name           category             sub_categories  \
# 0   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING  DIFFERENT_QUERY_STRUCTURE
# 3   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING           col name changes
# 5   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING           difference joins
# 4   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING        having versus where
# 1   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING    logic_filter_comparison
# 2   RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING   logic_filter_equal_check
# 7   RaduGabriel/BGE-M3-SQL        SAME MEAING                    aliases
# 6   RaduGabriel/BGE-M3-SQL        SAME MEAING   column order change only
# 13  RaduGabriel/BGE-M3-SQL        SAME MEAING        cte versus subquery
# 8   RaduGabriel/BGE-M3-SQL        SAME MEAING      date function between
# 9   RaduGabriel/BGE-M3-SQL        SAME MEAING       date function custom
# 10  RaduGabriel/BGE-M3-SQL        SAME MEAING    extract versus day/year
# 16  RaduGabriel/BGE-M3-SQL        SAME MEAING       join versus subquery
# 15  RaduGabriel/BGE-M3-SQL        SAME MEAING       over versus group by
# 12  RaduGabriel/BGE-M3-SQL        SAME MEAING         qualify versus cte
# 14  RaduGabriel/BGE-M3-SQL        SAME MEAING    qualify versus subquery
# 11  RaduGabriel/BGE-M3-SQL        SAME MEAING              regex and str
#
#      cosine_scores  ast_scores  seq_matcher_score  \
# 0   tensor(0.8125)    0.431818           0.637615
# 3   tensor(0.9006)    0.187500           0.786241
# 5   tensor(0.9568)    0.875000           0.957576
# 4   tensor(0.8720)    0.600000           0.746269
# 1   tensor(0.9968)    0.750000           0.995122
# 2   tensor(0.9937)    0.750000           0.992701
# 7   tensor(0.8752)    0.257576           0.420891
# 6   tensor(0.9963)    0.904762           0.476821
# 13  tensor(0.9704)    0.807692           0.699559
# 8   tensor(0.9825)    0.675000           0.952862
# 9   tensor(0.9588)    0.289474           0.901961
# 10  tensor(0.9844)    0.444444           0.758621
# 16  tensor(0.8486)    0.134615           0.688172
# 15  tensor(0.9446)    0.708333           0.638298
# 12  tensor(0.8899)    0.346154           0.470852
# 14  tensor(0.8967)    0.338235           0.494649
# 11  tensor(0.9586)    0.342105           0.633333
#
#                                               query_a  \
# 0   SELECT name FROM students WHERE class_id IN (S...
# 3   SELECT name FROM students WHERE class_id IN (S...
# 5   SELECT name FROM students WHERE class_id IN (S...
# 4   SELECT name FROM students WHERE class_id IN (S...
# 1   SELECT name FROM students WHERE class_id IN (S...
# 2   SELECT name FROM students WHERE class_id IN (S...
# 7   SELECT name FROM students WHERE class_id IN (S...
# 6   SELECT name FROM students WHERE class_id IN (S...
# 13  SELECT name FROM students WHERE class_id IN (S...
# 8   SELECT name FROM students WHERE class_id IN (S...
# 9   SELECT name FROM students WHERE class_id IN (S...
# 10  SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
# 12  SELECT name FROM students WHERE class_id IN (S...
# 14  SELECT name FROM students WHERE class_id IN (S...
# 11  SELECT name FROM students WHERE class_id IN (S...
#
#                                               query_b
# 0   SELECT name FROM students s LEFT JOIN classes ...
# 3   SELECT name FROM students s LEFT JOIN classes ...
# 5   SELECT name FROM students s LEFT JOIN classes ...
# 4   SELECT name FROM students s LEFT JOIN classes ...
# 1   SELECT name FROM students s LEFT JOIN classes ...
# 2   SELECT name FROM students s LEFT JOIN classes ...
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 6   SELECT name FROM students s LEFT JOIN classes ...
# 13  SELECT name FROM students s LEFT JOIN classes ...
# 8   SELECT name FROM students s LEFT JOIN classes ...
# 9   SELECT name FROM students s LEFT JOIN classes ...
# 10  SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...
# 12  SELECT name FROM students s LEFT JOIN classes ...
# 14  SELECT name FROM students s LEFT JOIN classes ...
# 11  SELECT name FROM students s LEFT JOIN classes ...

# %%
result[result.model_name == "dat-ai/bge-base-for_text2sql"].sort_values(by=["category", "sub_categories"])
# Out:
#                       model_name           category  \
# 0   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 3   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 5   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 4   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 1   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 2   dat-ai/bge-base-for_text2sql  DIFFERENT MEANING
# 7   dat-ai/bge-base-for_text2sql        SAME MEAING
# 6   dat-ai/bge-base-for_text2sql        SAME MEAING
# 13  dat-ai/bge-base-for_text2sql        SAME MEAING
# 8   dat-ai/bge-base-for_text2sql        SAME MEAING
# 9   dat-ai/bge-base-for_text2sql        SAME MEAING
# 10  dat-ai/bge-base-for_text2sql        SAME MEAING
# 16  dat-ai/bge-base-for_text2sql        SAME MEAING
# 15  dat-ai/bge-base-for_text2sql        SAME MEAING
# 12  dat-ai/bge-base-for_text2sql        SAME MEAING
# 14  dat-ai/bge-base-for_text2sql        SAME MEAING
# 11  dat-ai/bge-base-for_text2sql        SAME MEAING
#
#                sub_categories   cosine_scores  ast_scores  seq_matcher_score  \
# 0   DIFFERENT_QUERY_STRUCTURE  tensor(0.6551)    0.431818           0.637615
# 3            col name changes  tensor(0.7830)    0.187500           0.786241
# 5            difference joins  tensor(0.8712)    0.875000           0.957576
# 4         having versus where  tensor(0.7904)    0.600000           0.746269
# 1     logic_filter_comparison  tensor(0.9942)    0.750000           0.995122
# 2    logic_filter_equal_check  tensor(0.9924)    0.750000           0.992701
# 7                     aliases  tensor(0.7127)    0.257576           0.420891
# 6    column order change only  tensor(0.9822)    0.904762           0.476821
# 13        cte versus subquery  tensor(0.7602)    0.807692           0.699559
# 8       date function between  tensor(0.9396)    0.675000           0.952862
# 9        date function custom  tensor(0.6284)    0.289474           0.901961
# 10    extract versus day/year  tensor(0.8656)    0.444444           0.758621
# 16       join versus subquery  tensor(0.7393)    0.134615           0.688172
# 15       over versus group by  tensor(0.8470)    0.708333           0.638298
# 12         qualify versus cte  tensor(0.5253)    0.346154           0.470852
# 14    qualify versus subquery  tensor(0.5573)    0.338235           0.494649
# 11              regex and str  tensor(0.7512)    0.342105           0.633333
#
#                                               query_a  \
# 0   SELECT name FROM students WHERE class_id IN (S...
# 3   SELECT name FROM students WHERE class_id IN (S...
# 5   SELECT name FROM students WHERE class_id IN (S...
# 4   SELECT name FROM students WHERE class_id IN (S...
# 1   SELECT name FROM students WHERE class_id IN (S...
# 2   SELECT name FROM students WHERE class_id IN (S...
# 7   SELECT name FROM students WHERE class_id IN (S...
# 6   SELECT name FROM students WHERE class_id IN (S...
# 13  SELECT name FROM students WHERE class_id IN (S...
# 8   SELECT name FROM students WHERE class_id IN (S...
# 9   SELECT name FROM students WHERE class_id IN (S...
# 10  SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
# 12  SELECT name FROM students WHERE class_id IN (S...
# 14  SELECT name FROM students WHERE class_id IN (S...
# 11  SELECT name FROM students WHERE class_id IN (S...
#
#                                               query_b
# 0   SELECT name FROM students s LEFT JOIN classes ...
# 3   SELECT name FROM students s LEFT JOIN classes ...
# 5   SELECT name FROM students s LEFT JOIN classes ...
# 4   SELECT name FROM students s LEFT JOIN classes ...
# 1   SELECT name FROM students s LEFT JOIN classes ...
# 2   SELECT name FROM students s LEFT JOIN classes ...
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 6   SELECT name FROM students s LEFT JOIN classes ...
# 13  SELECT name FROM students s LEFT JOIN classes ...
# 8   SELECT name FROM students s LEFT JOIN classes ...
# 9   SELECT name FROM students s LEFT JOIN classes ...
# 10  SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...
# 12  SELECT name FROM students s LEFT JOIN classes ...
# 14  SELECT name FROM students s LEFT JOIN classes ...
# 11  SELECT name FROM students s LEFT JOIN classes ...

# %% [markdown]
# ## Result Analysis:
#
# * s2593817/sft-sql-embedding appear to be the best overall
# * RaduGabriel/BGE-M3-SQL produces high score for all
# * dat-ai/bge-base-for_text2sql appear to be doing better for the same meaing ones but does poorly in negative cases

# %% [markdown]
# ### All embedding models does poorly in logic filters, column name changes in filtering/groupbys, and also joins

# %%
result[result.sub_categories.isin(["logic_filter_comparison", "logic_filter_equal_check", 
                                  "col name changes", "difference joins"])].sort_values(by="sub_categories")
# Out:
#                      model_name           category            sub_categories  \
# 3    s2593817/sft-sql-embedding  DIFFERENT MEANING          col name changes
# 3        RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING          col name changes
# 3  dat-ai/bge-base-for_text2sql  DIFFERENT MEANING          col name changes
# 5    s2593817/sft-sql-embedding  DIFFERENT MEANING          difference joins
# 5        RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING          difference joins
# 5  dat-ai/bge-base-for_text2sql  DIFFERENT MEANING          difference joins
# 1    s2593817/sft-sql-embedding  DIFFERENT MEANING   logic_filter_comparison
# 1        RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING   logic_filter_comparison
# 1  dat-ai/bge-base-for_text2sql  DIFFERENT MEANING   logic_filter_comparison
# 2    s2593817/sft-sql-embedding  DIFFERENT MEANING  logic_filter_equal_check
# 2        RaduGabriel/BGE-M3-SQL  DIFFERENT MEANING  logic_filter_equal_check
# 2  dat-ai/bge-base-for_text2sql  DIFFERENT MEANING  logic_filter_equal_check
#
#     cosine_scores  ast_scores  seq_matcher_score  \
# 3  tensor(0.9711)      0.1875           0.786241
# 3  tensor(0.9006)      0.1875           0.786241
# 3  tensor(0.7830)      0.1875           0.786241
# 5  tensor(0.9739)      0.8750           0.957576
# 5  tensor(0.9568)      0.8750           0.957576
# 5  tensor(0.8712)      0.8750           0.957576
# 1  tensor(0.9975)      0.7500           0.995122
# 1  tensor(0.9968)      0.7500           0.995122
# 1  tensor(0.9942)      0.7500           0.995122
# 2  tensor(0.9796)      0.7500           0.992701
# 2  tensor(0.9937)      0.7500           0.992701
# 2  tensor(0.9924)      0.7500           0.992701
#
#                                              query_a  \
# 3  SELECT name FROM students WHERE class_id IN (S...
# 3  SELECT name FROM students WHERE class_id IN (S...
# 3  SELECT name FROM students WHERE class_id IN (S...
# 5  SELECT name FROM students WHERE class_id IN (S...
# 5  SELECT name FROM students WHERE class_id IN (S...
# 5  SELECT name FROM students WHERE class_id IN (S...
# 1  SELECT name FROM students WHERE class_id IN (S...
# 1  SELECT name FROM students WHERE class_id IN (S...
# 1  SELECT name FROM students WHERE class_id IN (S...
# 2  SELECT name FROM students WHERE class_id IN (S...
# 2  SELECT name FROM students WHERE class_id IN (S...
# 2  SELECT name FROM students WHERE class_id IN (S...
#
#                                              query_b
# 3  SELECT name FROM students s LEFT JOIN classes ...
# 3  SELECT name FROM students s LEFT JOIN classes ...
# 3  SELECT name FROM students s LEFT JOIN classes ...
# 5  SELECT name FROM students s LEFT JOIN classes ...
# 5  SELECT name FROM students s LEFT JOIN classes ...
# 5  SELECT name FROM students s LEFT JOIN classes ...
# 1  SELECT name FROM students s LEFT JOIN classes ...
# 1  SELECT name FROM students s LEFT JOIN classes ...
# 1  SELECT name FROM students s LEFT JOIN classes ...
# 2  SELECT name FROM students s LEFT JOIN classes ...
# 2  SELECT name FROM students s LEFT JOIN classes ...
# 2  SELECT name FROM students s LEFT JOIN classes ...

# %% [markdown]
# ### All embedding models does inconsistently well in similar meaning ones especially in join versus subquery, over versus group by and alias

# %%
result[result.sub_categories.isin(["join versus subquery", "aliases", "over versus group by"])].sort_values(by="sub_categories")
# Out:
#                       model_name     category        sub_categories  \
# 7     s2593817/sft-sql-embedding  SAME MEAING               aliases
# 7         RaduGabriel/BGE-M3-SQL  SAME MEAING               aliases
# 7   dat-ai/bge-base-for_text2sql  SAME MEAING               aliases
# 16    s2593817/sft-sql-embedding  SAME MEAING  join versus subquery
# 16        RaduGabriel/BGE-M3-SQL  SAME MEAING  join versus subquery
# 16  dat-ai/bge-base-for_text2sql  SAME MEAING  join versus subquery
# 15    s2593817/sft-sql-embedding  SAME MEAING  over versus group by
# 15        RaduGabriel/BGE-M3-SQL  SAME MEAING  over versus group by
# 15  dat-ai/bge-base-for_text2sql  SAME MEAING  over versus group by
#
#      cosine_scores  ast_scores  seq_matcher_score  \
# 7   tensor(0.5448)    0.257576           0.420891
# 7   tensor(0.8752)    0.257576           0.420891
# 7   tensor(0.7127)    0.257576           0.420891
# 16  tensor(0.5896)    0.134615           0.688172
# 16  tensor(0.8486)    0.134615           0.688172
# 16  tensor(0.7393)    0.134615           0.688172
# 15  tensor(0.7444)    0.708333           0.638298
# 15  tensor(0.9446)    0.708333           0.638298
# 15  tensor(0.8470)    0.708333           0.638298
#
#                                               query_a  \
# 7   SELECT name FROM students WHERE class_id IN (S...
# 7   SELECT name FROM students WHERE class_id IN (S...
# 7   SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 16  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
# 15  SELECT name FROM students WHERE class_id IN (S...
#
#                                               query_b
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 7   SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 16  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...
# 15  SELECT name FROM students s LEFT JOIN classes ...

# %% [markdown]
# ### The embedding model is good at handling minor syntactic variations where the keywords and structure remain similar.

# %% [markdown]
# ### Conclusion:
# This embedding model is effective at matching queries with minor syntactic differences but fails to capture the core logic of SQL. It cannot reliably distinguish between operators, join types, or clause functions (WHERE vs. HAVING), leading to dangerously incorrect assessments of similarity.
